# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
import requests
from config import weather_api_keys
from citipy import citipy

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)


cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 760

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys

# %%
# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print('------------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc,
                         })
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | olafsvik
# Processing Record 3 of Set 1 | matara
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | samarai
# Processing Record 9 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | benha
# City not found. Skipping...
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | bailen
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | la romana
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | leshukonskoye
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | nanortalik
# Processing Record 21 of Set 1 | necochea
# Processing Record 22 of Set 1 | sur
# Processing Record 23 of Set 1 | copiapo
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | saint george
# Processing Record 26 of Set 1 | kolokani
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | west wendover
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | kununurra
# Processing Record 34 of Set 1 | flinders
# Processing Record 35 of Set 1 | doha
# Processing Record 36 of Set 1 | broken hill
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | hovd
# Processing Record 39 of Set 1 | henties bay
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | bad bevensen
# Processing Record 43 of Set 1 | tautira
# Processing Record 44 of Set 1 | soria
# Processing Record 45 of Set 1 | marzuq
# Processing Record 46 of Set 1 | grindavik
# Processing Record 47 of Set 1 | toora-khem
# Processing Record 48 of Set 1 | nouadhibou
# Processing Record 49 of Set 1 | bardiyah
# Processing Record 50 of Set 1 | geraldton
# Processing Record 1 of Set 2 | benghazi
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | paamiut
# Processing Record 6 of Set 2 | carutapera
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | san quintin
# Processing Record 9 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | anchorage
# Processing Record 13 of Set 2 | verkh-usugli
# Processing Record 14 of Set 2 | brae
# Processing Record 15 of Set 2 | sungaipenuh
# Processing Record 16 of Set 2 | urucara
# Processing Record 17 of Set 2 | baruun-urt
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | bor
# Processing Record 20 of Set 2 | swan hill
# Processing Record 21 of Set 2 | lompoc
# Processing Record 22 of Set 2 | nemuro
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | catalina foothills
# Processing Record 25 of Set 2 | uyemskiy
# Processing Record 26 of Set 2 | andenes
# Processing Record 27 of Set 2 | burnie
# Processing Record 28 of Set 2 | novo aripuana
# Processing Record 29 of Set 2 | meulaboh
# Processing Record 30 of Set 2 | ballina
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | tasiilaq
# Processing Record 36 of Set 2 | aksu
# Processing Record 37 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 2 | marawi
# Processing Record 39 of Set 2 | punta arenas
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | balingasay
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | ventspils
# Processing Record 44 of Set 2 | gilbues
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | poum
# Processing Record 48 of Set 2 | yarmouth
# Processing Record 49 of Set 2 | vokhma
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | khor
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | richards bay
# Processing Record 5 of Set 3 | mokobeng
# Processing Record 6 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 3 | avera
# Processing Record 8 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | scottsbluff
# Processing Record 10 of Set 3 | grajau
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | buala
# Processing Record 14 of Set 3 | goma
# Processing Record 15 of Set 3 | taksimo
# Processing Record 16 of Set 3 | sabang
# Processing Record 17 of Set 3 | taltal
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | ribeira grande
# Processing Record 20 of Set 3 | yar-sale
# Processing Record 21 of Set 3 | bondo
# Processing Record 22 of Set 3 | rio gallegos
# Processing Record 23 of Set 3 | ravar
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | vila franca do campo
# Processing Record 26 of Set 3 | praia da vitoria
# Processing Record 27 of Set 3 | hamilton
# Processing Record 28 of Set 3 | severnyy
# Processing Record 29 of Set 3 | brnakot
# Processing Record 30 of Set 3 | kachikau
# City not found. Skipping...
# Processing Record 31 of Set 3 | rawson
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | gizo
# Processing Record 34 of Set 3 | jalu
# Processing Record 35 of Set 3 | flin flon
# Processing Record 36 of Set 3 | klaksvik
# Processing Record 37 of Set 3 | farmington
# Processing Record 38 of Set 3 | port hardy
# Processing Record 39 of Set 3 | upernavik
# Processing Record 40 of Set 3 | bilibino
# Processing Record 41 of Set 3 | vangaindrano
# Processing Record 42 of Set 3 | belize
# Processing Record 43 of Set 3 | fairbanks
# Processing Record 44 of Set 3 | evensk
# Processing Record 45 of Set 3 | yellowknife
# Processing Record 46 of Set 3 | zhanaozen
# Processing Record 47 of Set 3 | antofagasta
# Processing Record 48 of Set 3 | slyudyanka
# Processing Record 49 of Set 3 | botou
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | tuatapere
# Processing Record 2 of Set 4 | darab
# Processing Record 3 of Set 4 | vila velha
# Processing Record 4 of Set 4 | acajutla
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | yaan
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | comodoro rivadavia
# Processing Record 9 of Set 4 | hobart
# Processing Record 10 of Set 4 | ostrovnoy
# Processing Record 11 of Set 4 | sumbe
# Processing Record 12 of Set 4 | abnub
# Processing Record 13 of Set 4 | ambulu
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | guanhaes
# Processing Record 16 of Set 4 | ambilobe
# Processing Record 17 of Set 4 | acandi
# Processing Record 18 of Set 4 | imbituba
# Processing Record 19 of Set 4 | plettenberg bay
# Processing Record 20 of Set 4 | fare
# Processing Record 21 of Set 4 | pandan
# Processing Record 22 of Set 4 | salinopolis
# Processing Record 23 of Set 4 | pasinler
# Processing Record 24 of Set 4 | margate
# Processing Record 25 of Set 4 | bethel
# Processing Record 26 of Set 4 | lorengau
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | bengkulu
# Processing Record 29 of Set 4 | dongzhen
# Processing Record 30 of Set 4 | el badari
# City not found. Skipping...
# Processing Record 31 of Set 4 | san cristobal
# Processing Record 32 of Set 4 | tongliao
# Processing Record 33 of Set 4 | ust-kan
# Processing Record 34 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 4 | channel-port aux basques
# Processing Record 36 of Set 4 | haines junction
# Processing Record 37 of Set 4 | indian head
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 4 | hobyo
# Processing Record 41 of Set 4 | constitucion
# Processing Record 42 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 4 | bud
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | mayo
# Processing Record 46 of Set 4 | vila
# Processing Record 47 of Set 4 | sao sebastiao
# Processing Record 48 of Set 4 | okhotsk
# Processing Record 49 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | nioro
# Processing Record 2 of Set 5 | narrabri
# Processing Record 3 of Set 5 | ixtapa
# Processing Record 4 of Set 5 | qabis
# City not found. Skipping...
# Processing Record 5 of Set 5 | harnosand
# Processing Record 6 of Set 5 | jumla
# Processing Record 7 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 5 | boa vista
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | batalha
# Processing Record 11 of Set 5 | saskylakh
# Processing Record 12 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 13 of Set 5 | jati
# Processing Record 14 of Set 5 | kaeo
# Processing Record 15 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 16 of Set 5 | inhambane
# Processing Record 17 of Set 5 | luderitz
# Processing Record 18 of Set 5 | santa isabel do rio negro
# Processing Record 19 of Set 5 | portel
# Processing Record 20 of Set 5 | mosquera
# Processing Record 21 of Set 5 | ajdabiya
# Processing Record 22 of Set 5 | tura
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | talah
# City not found. Skipping...
# Processing Record 25 of Set 5 | beringovskiy
# Processing Record 26 of Set 5 | cabo san lucas
# Processing Record 27 of Set 5 | pevek
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | provideniya
# Processing Record 30 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 5 | vallenar
# Processing Record 32 of Set 5 | new norfolk
# Processing Record 33 of Set 5 | bom jesus
# Processing Record 34 of Set 5 | lasa
# Processing Record 35 of Set 5 | sarahan
# Processing Record 36 of Set 5 | raton
# Processing Record 37 of Set 5 | leningradskiy
# Processing Record 38 of Set 5 | sobolevo
# Processing Record 39 of Set 5 | kirakira
# Processing Record 40 of Set 5 | atambua
# Processing Record 41 of Set 5 | afua
# Processing Record 42 of Set 5 | anloga
# Processing Record 43 of Set 5 | lima
# Processing Record 44 of Set 5 | garowe
# Processing Record 45 of Set 5 | ancud
# Processing Record 46 of Set 5 | usinsk
# Processing Record 47 of Set 5 | mattawa
# Processing Record 48 of Set 5 | qaanaaq
# Processing Record 49 of Set 5 | tiksi
# Processing Record 50 of Set 5 | husavik
# Processing Record 1 of Set 6 | luxor
# Processing Record 2 of Set 6 | salalah
# Processing Record 3 of Set 6 | qui nhon
# Processing Record 4 of Set 6 | senmonorom
# City not found. Skipping...
# Processing Record 5 of Set 6 | chuy
# Processing Record 6 of Set 6 | longyearbyen
# Processing Record 7 of Set 6 | porto torres
# Processing Record 8 of Set 6 | hasaki
# Processing Record 9 of Set 6 | dod ballapur
# Processing Record 10 of Set 6 | huambo
# Processing Record 11 of Set 6 | wageningen
# Processing Record 12 of Set 6 | kaitangata
# Processing Record 13 of Set 6 | davidson
# Processing Record 14 of Set 6 | kavieng
# Processing Record 15 of Set 6 | nicolas bravo
# Processing Record 16 of Set 6 | kalmunai
# Processing Record 17 of Set 6 | bonthe
# Processing Record 18 of Set 6 | polis
# Processing Record 19 of Set 6 | belaya gora
# Processing Record 20 of Set 6 | faya
# Processing Record 21 of Set 6 | mitzic
# Processing Record 22 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 6 | shahrud
# Processing Record 24 of Set 6 | stornoway
# Processing Record 25 of Set 6 | vanimo
# Processing Record 26 of Set 6 | monrovia
# Processing Record 27 of Set 6 | talara
# Processing Record 28 of Set 6 | nara
# Processing Record 29 of Set 6 | worthington
# Processing Record 30 of Set 6 | codrington
# Processing Record 31 of Set 6 | jaicos
# Processing Record 32 of Set 6 | acarau
# Processing Record 33 of Set 6 | songkhla
# Processing Record 34 of Set 6 | curillo
# Processing Record 35 of Set 6 | griffith
# Processing Record 36 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 6 | half moon bay
# Processing Record 38 of Set 6 | ketchikan
# Processing Record 39 of Set 6 | mersing
# Processing Record 40 of Set 6 | keokuk
# Processing Record 41 of Set 6 | itacoatiara
# Processing Record 42 of Set 6 | bulach
# Processing Record 43 of Set 6 | mbandaka
# Processing Record 44 of Set 6 | naze
# Processing Record 45 of Set 6 | namibe
# Processing Record 46 of Set 6 | luga
# Processing Record 47 of Set 6 | coihaique
# Processing Record 48 of Set 6 | sao filipe
# Processing Record 49 of Set 6 | kudahuvadhoo
# Processing Record 50 of Set 6 | dunedin
# Processing Record 1 of Set 7 | san jeronimo
# Processing Record 2 of Set 7 | pacific grove
# Processing Record 3 of Set 7 | zhigansk
# Processing Record 4 of Set 7 | ankara
# Processing Record 5 of Set 7 | leua
# Processing Record 6 of Set 7 | morro bay
# Processing Record 7 of Set 7 | charters towers
# Processing Record 8 of Set 7 | college
# Processing Record 9 of Set 7 | ballitoville
# Processing Record 10 of Set 7 | hualmay
# Processing Record 11 of Set 7 | nishihara
# Processing Record 12 of Set 7 | katsuura
# Processing Record 13 of Set 7 | batagay-alyta
# Processing Record 14 of Set 7 | narovchat
# Processing Record 15 of Set 7 | airai
# Processing Record 16 of Set 7 | grand gaube
# Processing Record 17 of Set 7 | bambous virieux
# Processing Record 18 of Set 7 | naryan-mar
# Processing Record 19 of Set 7 | imeni zhelyabova
# Processing Record 20 of Set 7 | santa cruz del sur
# Processing Record 21 of Set 7 | lavrentiya
# Processing Record 22 of Set 7 | hambantota
# Processing Record 23 of Set 7 | vostok
# Processing Record 24 of Set 7 | krasnoselkup
# Processing Record 25 of Set 7 | kenora
# Processing Record 26 of Set 7 | manzanillo
# Processing Record 27 of Set 7 | vikhorevka
# Processing Record 28 of Set 7 | kang
# Processing Record 29 of Set 7 | ngunguru
# Processing Record 30 of Set 7 | lebu
# Processing Record 31 of Set 7 | denpasar
# Processing Record 32 of Set 7 | pontes e lacerda
# Processing Record 33 of Set 7 | la rioja
# Processing Record 34 of Set 7 | chinhoyi
# Processing Record 35 of Set 7 | dubi
# Processing Record 36 of Set 7 | faanui
# Processing Record 37 of Set 7 | walvis bay
# Processing Record 38 of Set 7 | plouzane
# Processing Record 39 of Set 7 | sinnamary
# Processing Record 40 of Set 7 | marigot
# Processing Record 41 of Set 7 | saint-francois
# Processing Record 42 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 7 | quatre cocos
# Processing Record 44 of Set 7 | kumylzhenskaya
# Processing Record 45 of Set 7 | malyye derbety
# Processing Record 46 of Set 7 | esperance
# Processing Record 47 of Set 7 | guerrero negro
# Processing Record 48 of Set 7 | mount gambier
# Processing Record 49 of Set 7 | lagoa
# Processing Record 50 of Set 7 | sekoma
# Processing Record 1 of Set 8 | west bay
# Processing Record 2 of Set 8 | sayyan
# Processing Record 3 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 8 | malakal
# Processing Record 6 of Set 8 | raya
# Processing Record 7 of Set 8 | bathsheba
# Processing Record 8 of Set 8 | vao
# Processing Record 9 of Set 8 | los llanos de aridane
# Processing Record 10 of Set 8 | wanaka
# Processing Record 11 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 8 | bozoum
# Processing Record 13 of Set 8 | nago
# Processing Record 14 of Set 8 | japeri
# Processing Record 15 of Set 8 | port lincoln
# Processing Record 16 of Set 8 | goure
# Processing Record 17 of Set 8 | corn island
# Processing Record 18 of Set 8 | porgera
# Processing Record 19 of Set 8 | kuusamo
# Processing Record 20 of Set 8 | san policarpo
# Processing Record 21 of Set 8 | marrakesh
# Processing Record 22 of Set 8 | hidalgo
# Processing Record 23 of Set 8 | laguna
# Processing Record 24 of Set 8 | huazolotitlan
# City not found. Skipping...
# Processing Record 25 of Set 8 | carauari
# Processing Record 26 of Set 8 | istra
# Processing Record 27 of Set 8 | mount isa
# Processing Record 28 of Set 8 | puerto escondido
# Processing Record 29 of Set 8 | luganville
# Processing Record 30 of Set 8 | russell
# Processing Record 31 of Set 8 | mogadishu
# Processing Record 32 of Set 8 | bangaon
# Processing Record 33 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 8 | kemijarvi
# Processing Record 35 of Set 8 | sendhwa
# Processing Record 36 of Set 8 | chapais
# Processing Record 37 of Set 8 | moose factory
# Processing Record 38 of Set 8 | rockhampton
# Processing Record 39 of Set 8 | alikalia
# Processing Record 40 of Set 8 | meiktila
# Processing Record 41 of Set 8 | dromolaxia
# Processing Record 42 of Set 8 | mayumba
# Processing Record 43 of Set 8 | abu samrah
# Processing Record 44 of Set 8 | alekseyevsk
# Processing Record 45 of Set 8 | albenga
# Processing Record 46 of Set 8 | rudnogorsk
# Processing Record 47 of Set 8 | inuvik
# Processing Record 48 of Set 8 | saint-pierre
# Processing Record 49 of Set 8 | gimli
# Processing Record 50 of Set 8 | bitung
# Processing Record 1 of Set 9 | ozernovskiy
# Processing Record 2 of Set 9 | te anau
# Processing Record 3 of Set 9 | san isidro
# Processing Record 4 of Set 9 | darhan
# Processing Record 5 of Set 9 | fortuna
# Processing Record 6 of Set 9 | oyama
# Processing Record 7 of Set 9 | mitsamiouli
# Processing Record 8 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 9 of Set 9 | rabo de peixe
# Processing Record 10 of Set 9 | tecoanapa
# Processing Record 11 of Set 9 | porbandar
# Processing Record 12 of Set 9 | balboa
# Processing Record 13 of Set 9 | itaueira
# Processing Record 14 of Set 9 | oistins
# Processing Record 15 of Set 9 | beloha
# Processing Record 16 of Set 9 | grand-lahou
# Processing Record 17 of Set 9 | auki
# Processing Record 18 of Set 9 | hofn
# Processing Record 19 of Set 9 | diffa
# Processing Record 20 of Set 9 | padang
# Processing Record 21 of Set 9 | pisco
# Processing Record 22 of Set 9 | calvinia
# Processing Record 23 of Set 9 | saint-augustin
# Processing Record 24 of Set 9 | kukes
# Processing Record 25 of Set 9 | ahipara
# Processing Record 26 of Set 9 | guanica
# Processing Record 27 of Set 9 | karaton
# Processing Record 28 of Set 9 | maceio
# Processing Record 29 of Set 9 | sorland
# Processing Record 30 of Set 9 | gazojak
# Processing Record 31 of Set 9 | willowmore
# Processing Record 32 of Set 9 | semnan
# Processing Record 33 of Set 9 | atakpame
# Processing Record 34 of Set 9 | orodara
# Processing Record 35 of Set 9 | gwadar
# Processing Record 36 of Set 9 | korla
# Processing Record 37 of Set 9 | teguldet
# Processing Record 38 of Set 9 | isiro
# Processing Record 39 of Set 9 | ambatondrazaka
# Processing Record 40 of Set 9 | cockburn town
# Processing Record 41 of Set 9 | kirksville
# Processing Record 42 of Set 9 | erenhot
# Processing Record 43 of Set 9 | christchurch
# Processing Record 44 of Set 9 | severnoye
# Processing Record 45 of Set 9 | bam
# Processing Record 46 of Set 9 | tungor
# Processing Record 47 of Set 9 | aklavik
# Processing Record 48 of Set 9 | shupiyan
# Processing Record 49 of Set 9 | manjacaze
# Processing Record 50 of Set 9 | riachao das neves
# Processing Record 1 of Set 10 | yafran
# Processing Record 2 of Set 10 | mayor pablo lagerenza
# Processing Record 3 of Set 10 | miraflores
# Processing Record 4 of Set 10 | sikeston
# Processing Record 5 of Set 10 | north bend
# Processing Record 6 of Set 10 | todos santos
# Processing Record 7 of Set 10 | sarrebourg
# Processing Record 8 of Set 10 | agadez
# Processing Record 9 of Set 10 | stawell
# Processing Record 10 of Set 10 | myaundzha
# Processing Record 11 of Set 10 | kutum
# Processing Record 12 of Set 10 | kasempa
# Processing Record 13 of Set 10 | safford
# Processing Record 14 of Set 10 | umea
# Processing Record 15 of Set 10 | clarence town
# Processing Record 16 of Set 10 | oranjemund
# Processing Record 17 of Set 10 | cabedelo
# Processing Record 18 of Set 10 | mahibadhoo
# Processing Record 19 of Set 10 | tripoli
# Processing Record 20 of Set 10 | gumdag
# Processing Record 21 of Set 10 | suntar
# Processing Record 22 of Set 10 | kuala terengganu
# Processing Record 23 of Set 10 | oneonta
# Processing Record 24 of Set 10 | barahona
# Processing Record 25 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 26 of Set 10 | caravelas
# Processing Record 27 of Set 10 | fort nelson
# Processing Record 28 of Set 10 | bandipur
# Processing Record 29 of Set 10 | coffs harbour
# Processing Record 30 of Set 10 | tambun
# Processing Record 31 of Set 10 | sibolga
# Processing Record 32 of Set 10 | itaituba
# Processing Record 33 of Set 10 | acapulco
# Processing Record 34 of Set 10 | nguruka
# Processing Record 35 of Set 10 | puerto del rosario
# Processing Record 36 of Set 10 | seminole
# Processing Record 37 of Set 10 | egvekinot
# Processing Record 38 of Set 10 | lazaro cardenas
# Processing Record 39 of Set 10 | cairns
# Processing Record 40 of Set 10 | atbasar
# Processing Record 41 of Set 10 | muzhi
# Processing Record 42 of Set 10 | raudeberg
# Processing Record 43 of Set 10 | kikwit
# Processing Record 44 of Set 10 | sandpoint
# Processing Record 45 of Set 10 | ausa
# Processing Record 46 of Set 10 | crib point
# Processing Record 47 of Set 10 | calama
# Processing Record 48 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 10 | bubaque
# Processing Record 50 of Set 10 | nikel
# Processing Record 1 of Set 11 | kieta
# Processing Record 2 of Set 11 | vestmanna
# Processing Record 3 of Set 11 | palmer
# Processing Record 4 of Set 11 | omsukchan
# Processing Record 5 of Set 11 | anadyr
# Processing Record 6 of Set 11 | beckley
# Processing Record 7 of Set 11 | bartica
# Processing Record 8 of Set 11 | brasileia
# Processing Record 9 of Set 11 | port-gentil
# Processing Record 10 of Set 11 | dingle
# Processing Record 11 of Set 11 | kribi
# Processing Record 12 of Set 11 | powell river
# Processing Record 13 of Set 11 | port blair
# Processing Record 14 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 11 | rocha
# Processing Record 16 of Set 11 | hay river
# Processing Record 17 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 18 of Set 11 | ayan
# Processing Record 19 of Set 11 | yulara
# Processing Record 20 of Set 11 | vestmannaeyjar
# Processing Record 21 of Set 11 | oga
# Processing Record 22 of Set 11 | sakaiminato
# Processing Record 23 of Set 11 | hurghada
# Processing Record 24 of Set 11 | lermontovka
# Processing Record 25 of Set 11 | guaruja
# Processing Record 26 of Set 11 | bayanday
# Processing Record 27 of Set 11 | voyinka
# Processing Record 28 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 11 | cochabamba
# Processing Record 30 of Set 11 | forio
# Processing Record 31 of Set 11 | ust-tsilma
# Processing Record 32 of Set 11 | pangnirtung
# Processing Record 33 of Set 11 | amga
# Processing Record 34 of Set 11 | nicoya
# Processing Record 35 of Set 11 | solnechnyy
# Processing Record 36 of Set 11 | bondoukou
# Processing Record 37 of Set 11 | yonibana
# Processing Record 38 of Set 11 | kuzino
# Processing Record 39 of Set 11 | vorontsovka
# Processing Record 40 of Set 11 | benjamin constant
# Processing Record 41 of Set 11 | sal rei
# Processing Record 42 of Set 11 | barberton
# Processing Record 43 of Set 11 | ust-kuyga
# Processing Record 44 of Set 11 | mar del plata
# Processing Record 45 of Set 11 | umm kaddadah
# Processing Record 46 of Set 11 | portland
# Processing Record 47 of Set 11 | alofi
# Processing Record 48 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 11 | arkhara
# Processing Record 50 of Set 11 | coos bay
# Processing Record 1 of Set 12 | cedar city
# Processing Record 2 of Set 12 | wamba
# Processing Record 3 of Set 12 | itoman
# Processing Record 4 of Set 12 | dauphin
# Processing Record 5 of Set 12 | huron
# Processing Record 6 of Set 12 | kahului
# Processing Record 7 of Set 12 | belen
# Processing Record 8 of Set 12 | bogale
# Processing Record 9 of Set 12 | puerto cabezas
# Processing Record 10 of Set 12 | akyab
# Processing Record 11 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 12 of Set 12 | ishigaki
# Processing Record 13 of Set 12 | tirlyanskiy
# Processing Record 14 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 15 of Set 12 | sarangani
# Processing Record 16 of Set 12 | severo-yeniseyskiy
# Processing Record 17 of Set 12 | coahuayana
# Processing Record 18 of Set 12 | grabovo
# Processing Record 19 of Set 12 | russkaya polyana
# Processing Record 20 of Set 12 | rychnov nad kneznou
# Processing Record 21 of Set 12 | strezhevoy
# Processing Record 22 of Set 12 | kruisfontein
# Processing Record 23 of Set 12 | palafrugell
# Processing Record 24 of Set 12 | port hawkesbury
# Processing Record 25 of Set 12 | north platte
# Processing Record 26 of Set 12 | loveland
# Processing Record 27 of Set 12 | champerico
# Processing Record 28 of Set 12 | luau
# Processing Record 29 of Set 12 | kristinehamn
# Processing Record 30 of Set 12 | yumen
# Processing Record 31 of Set 12 | berbera
# Processing Record 32 of Set 12 | xuddur
# Processing Record 33 of Set 12 | vagur
# Processing Record 34 of Set 12 | caohai
# Processing Record 35 of Set 12 | yerbogachen
# Processing Record 36 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 12 | ranong
# Processing Record 38 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 39 of Set 12 | clyde river
# Processing Record 40 of Set 12 | kavaratti
# Processing Record 41 of Set 12 | nador
# Processing Record 42 of Set 12 | aykhal
# Processing Record 43 of Set 12 | pacifica
# Processing Record 44 of Set 12 | callaguip
# Processing Record 45 of Set 12 | trelew
# Processing Record 46 of Set 12 | kulhudhuffushi
# Processing Record 47 of Set 12 | agde
# Processing Record 48 of Set 12 | moron
# Processing Record 49 of Set 12 | quang ngai
# Processing Record 50 of Set 12 | rio grande
# Processing Record 1 of Set 13 | moyale
# Processing Record 2 of Set 13 | srednekolymsk
# Processing Record 3 of Set 13 | barraute
# Processing Record 4 of Set 13 | ossora
# Processing Record 5 of Set 13 | andradas
# Processing Record 6 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 13 | erzin
# Processing Record 8 of Set 13 | elbistan
# Processing Record 9 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 10 of Set 13 | krasnyye baki
# Processing Record 11 of Set 13 | koroni
# Processing Record 12 of Set 13 | enumclaw
# Processing Record 13 of Set 13 | mackay
# Processing Record 14 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 13 | beyneu
# Processing Record 16 of Set 13 | marsa matruh
# Processing Record 17 of Set 13 | port hedland
# Processing Record 18 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 13 | durban
# Processing Record 20 of Set 13 | lafiagi
# Processing Record 21 of Set 13 | asau
# Processing Record 22 of Set 13 | ulagan
# Processing Record 23 of Set 13 | abu dhabi
# Processing Record 24 of Set 13 | cukai
# Processing Record 25 of Set 13 | eureka
# Processing Record 26 of Set 13 | houma
# Processing Record 27 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 13 | san pedro
# Processing Record 29 of Set 13 | bahia blanca
# Processing Record 30 of Set 13 | vakhrushev
# Processing Record 31 of Set 13 | ulladulla
# Processing Record 32 of Set 13 | ilulissat
# Processing Record 33 of Set 13 | zhoucheng
# Processing Record 34 of Set 13 | olga
# Processing Record 35 of Set 13 | edgewater
# Processing Record 36 of Set 13 | santa maria
# Processing Record 37 of Set 13 | pangkalanbuun
# Processing Record 38 of Set 13 | berlevag
# Processing Record 39 of Set 13 | uzumlu
# City not found. Skipping...
# Processing Record 40 of Set 13 | axim
# Processing Record 41 of Set 13 | simao
# Processing Record 42 of Set 13 | bima
# Processing Record 43 of Set 13 | pouebo
# Processing Record 44 of Set 13 | jiazi
# Processing Record 45 of Set 13 | guigue
# Processing Record 46 of Set 13 | igunga
# Processing Record 47 of Set 13 | gat
# Processing Record 48 of Set 13 | juwana
# Processing Record 49 of Set 13 | makaha
# Processing Record 50 of Set 13 | boende
# Processing Record 1 of Set 14 | laredo
# Processing Record 2 of Set 14 | piacabucu
# Processing Record 3 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 4 of Set 14 | muros
# Processing Record 5 of Set 14 | kamina
# Processing Record 6 of Set 14 | georgiyevka
# Processing Record 7 of Set 14 | panorama
# Processing Record 8 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 9 of Set 14 | byron bay
# Processing Record 10 of Set 14 | karema
# Processing Record 11 of Set 14 | san luis
# Processing Record 12 of Set 14 | casambalangan
# Processing Record 13 of Set 14 | baguanos
# Processing Record 14 of Set 14 | miri
# Processing Record 15 of Set 14 | kloulklubed
# Processing Record 16 of Set 14 | nocupetaro
# Processing Record 17 of Set 14 | swellendam
# Processing Record 18 of Set 14 | tambacounda
# Processing Record 19 of Set 14 | svetlyy
# Processing Record 20 of Set 14 | misratah
# Processing Record 21 of Set 14 | scarborough
# Processing Record 22 of Set 14 | havre-saint-pierre
# Processing Record 23 of Set 14 | vostochnyy
# Processing Record 24 of Set 14 | tingo maria
# Processing Record 25 of Set 14 | weihai
# Processing Record 26 of Set 14 | cedar rapids
# Processing Record 27 of Set 14 | samfya
# Processing Record 28 of Set 14 | turukhansk
# Processing Record 29 of Set 14 | shingu
# Processing Record 30 of Set 14 | washington
# Processing Record 31 of Set 14 | magadan
# Processing Record 32 of Set 14 | leshan
# Processing Record 33 of Set 14 | aleysk
# Processing Record 34 of Set 14 | cayenne
# Processing Record 35 of Set 14 | adrar
# Processing Record 36 of Set 14 | awbari
# Processing Record 37 of Set 14 | angoram
# Processing Record 38 of Set 14 | maxixe
# Processing Record 39 of Set 14 | tucuman
# Processing Record 40 of Set 14 | ukiah
# Processing Record 41 of Set 14 | mukhen
# Processing Record 42 of Set 14 | honningsvag
# Processing Record 43 of Set 14 | aasiaat
# Processing Record 44 of Set 14 | manggar
# Processing Record 45 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 46 of Set 14 | namatanai
# Processing Record 47 of Set 14 | arinos
# Processing Record 48 of Set 14 | minab
# Processing Record 49 of Set 14 | pemberton
# Processing Record 50 of Set 14 | privodino
# Processing Record 1 of Set 15 | chimoio
# Processing Record 2 of Set 15 | ottumwa
# Processing Record 3 of Set 15 | nanuque
# Processing Record 4 of Set 15 | roebourne
# Processing Record 5 of Set 15 | tailai
# Processing Record 6 of Set 15 | gambela
# Processing Record 7 of Set 15 | nyaunglebin
# Processing Record 8 of Set 15 | kendari
# Processing Record 9 of Set 15 | athabasca
# Processing Record 10 of Set 15 | sabancuy
# Processing Record 11 of Set 15 | iralaya
# Processing Record 12 of Set 15 | talesh
# City not found. Skipping...
# Processing Record 13 of Set 15 | del rio
# Processing Record 14 of Set 15 | bakel
# Processing Record 15 of Set 15 | san matias
# Processing Record 16 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 15 | conde
# Processing Record 18 of Set 15 | zhongxing
# Processing Record 19 of Set 15 | pierre
# Processing Record 20 of Set 15 | douglas
# Processing Record 21 of Set 15 | noshiro
# Processing Record 22 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 15 | yangambi
# Processing Record 24 of Set 15 | jiexiu
# Processing Record 25 of Set 15 | camacha
# Processing Record 26 of Set 15 | gaoua
# Processing Record 27 of Set 15 | mudgee
# Processing Record 28 of Set 15 | iracoubo
# Processing Record 29 of Set 15 | borama
# City not found. Skipping...
# Processing Record 30 of Set 15 | kathu
# Processing Record 31 of Set 15 | shankargarh
# Processing Record 32 of Set 15 | guangyuan
# Processing Record 33 of Set 15 | komsomolskiy
# Processing Record 34 of Set 15 | kholmogory
# Processing Record 35 of Set 15 | miracema do tocantins
# Processing Record 36 of Set 15 | le port
# Processing Record 37 of Set 15 | along
# Processing Record 38 of Set 15 | miles city
# Processing Record 39 of Set 15 | buin
# Processing Record 40 of Set 15 | mutis
# Processing Record 41 of Set 15 | kangaatsiaq
# Processing Record 42 of Set 15 | polunochnoye
# Processing Record 43 of Set 15 | humboldt
# Processing Record 44 of Set 15 | parana
# Processing Record 45 of Set 15 | maldonado
# Processing Record 46 of Set 15 | surt
# Processing Record 47 of Set 15 | gijon
# Processing Record 48 of Set 15 | daud khel
# Processing Record 49 of Set 15 | pestretsy
# Processing Record 50 of Set 15 | larsnes
# Processing Record 1 of Set 16 | harper
# Processing Record 2 of Set 16 | chabahar
# Processing Record 3 of Set 16 | san carlos de bariloche
# Processing Record 4 of Set 16 | troitsko-pechorsk
# Processing Record 5 of Set 16 | krasnogvardeyskiy
# Processing Record 6 of Set 16 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 16 | vaitape
# Processing Record 8 of Set 16 | tonantins
# Processing Record 9 of Set 16 | concepcion
# Processing Record 10 of Set 16 | aswan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 760

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Albany  42.6001  -73.9662     53.37        47           5        1.01
# 1  Olafsvik  64.8945  -23.7142     42.40        74          89       14.20
# 2    Matara   5.9485   80.5353     76.24        87         100        1.90
# 3   Ushuaia -54.8000  -68.3000     58.66        55          75       14.97
# 4    Avarua -21.2078 -159.7750     77.05        65          75        8.05
#
#   Country Current Description
# 0      US           clear sky
# 1      IS     overcast clouds
# 2      LK       moderate rain
# 3      AR       broken clouds
# 4      CK       broken clouds

# %%
city_data_df.count()
# Out:
# City                   703
# Lat                    703
# Lng                    703
# Max Temp               703
# Humidity               703
# Cloudiness             703
# Wind Speed             703
# Country                703
# Current Description    703
# dtype: int64

# %%
output_data_file = 'Weatherpy_database.csv'
city_data_df.to_csv(output_data_file, index_label='City_ID')
