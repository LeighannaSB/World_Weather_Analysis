# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
import requests
from config import weather_api_keys
from citipy import citipy

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)


cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 731

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys

# %%
# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print('------------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | vila
# Processing Record 6 of Set 1 | agirish
# Processing Record 7 of Set 1 | vardo
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | usogorsk
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | namibe
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | wisconsin rapids
# Processing Record 15 of Set 1 | juba
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | mahina
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | san quintin
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | mayo
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | logan
# Processing Record 29 of Set 1 | los llanos de aridane
# Processing Record 30 of Set 1 | sangmelima
# Processing Record 31 of Set 1 | winslow
# Processing Record 32 of Set 1 | la ronge
# Processing Record 33 of Set 1 | isangel
# Processing Record 34 of Set 1 | mount gambier
# Processing Record 35 of Set 1 | saint anthony
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | bengkulu
# Processing Record 38 of Set 1 | naryan-mar
# Processing Record 39 of Set 1 | tulsipur
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | luderitz
# Processing Record 42 of Set 1 | lawrence
# Processing Record 43 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 44 of Set 1 | resistencia
# Processing Record 45 of Set 1 | mount isa
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | chapada dos guimaraes
# Processing Record 48 of Set 1 | meulaboh
# Processing Record 49 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 1 | coihaique
# Processing Record 1 of Set 2 | shu
# Processing Record 2 of Set 2 | sibolga
# Processing Record 3 of Set 2 | roald
# Processing Record 4 of Set 2 | saint george
# Processing Record 5 of Set 2 | goya
# Processing Record 6 of Set 2 | sinnamary
# Processing Record 7 of Set 2 | adrar
# Processing Record 8 of Set 2 | henties bay
# Processing Record 9 of Set 2 | shingu
# Processing Record 10 of Set 2 | cockburn town
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | sitka
# Processing Record 14 of Set 2 | haines junction
# Processing Record 15 of Set 2 | kerki
# City not found. Skipping...
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | oistins
# Processing Record 18 of Set 2 | ahipara
# Processing Record 19 of Set 2 | moerai
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | kavaratti
# Processing Record 22 of Set 2 | narsaq
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | baracoa
# Processing Record 25 of Set 2 | besancon
# Processing Record 26 of Set 2 | caidian
# Processing Record 27 of Set 2 | hambantota
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | anloga
# Processing Record 33 of Set 2 | berdigestyakh
# Processing Record 34 of Set 2 | margate
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | port macquarie
# Processing Record 37 of Set 2 | pathein
# Processing Record 38 of Set 2 | yerbogachen
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | palu
# Processing Record 41 of Set 2 | novo oriente
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | swan river
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | aksarka
# Processing Record 47 of Set 2 | riviere-au-renard
# Processing Record 48 of Set 2 | ormoz
# Processing Record 49 of Set 2 | pitimbu
# Processing Record 50 of Set 2 | rio gallegos
# Processing Record 1 of Set 3 | huilong
# Processing Record 2 of Set 3 | hobart
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 3 | mayumba
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | iwanai
# Processing Record 9 of Set 3 | esperance
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | faya
# Processing Record 12 of Set 3 | grenville
# Processing Record 13 of Set 3 | tautira
# Processing Record 14 of Set 3 | grand gaube
# Processing Record 15 of Set 3 | ucluelet
# Processing Record 16 of Set 3 | port hedland
# Processing Record 17 of Set 3 | la tiza
# Processing Record 18 of Set 3 | riyadh
# Processing Record 19 of Set 3 | quthing
# Processing Record 20 of Set 3 | fairbanks
# Processing Record 21 of Set 3 | flin flon
# Processing Record 22 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 3 | atuona
# Processing Record 27 of Set 3 | vila velha
# Processing Record 28 of Set 3 | saskylakh
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | villa carlos paz
# Processing Record 31 of Set 3 | erzurum
# Processing Record 32 of Set 3 | yumen
# Processing Record 33 of Set 3 | buin
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 3 | rocha
# Processing Record 37 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 3 | hurghada
# Processing Record 39 of Set 3 | provideniya
# Processing Record 40 of Set 3 | kaitangata
# Processing Record 41 of Set 3 | laguna
# Processing Record 42 of Set 3 | naze
# Processing Record 43 of Set 3 | hami
# Processing Record 44 of Set 3 | beloha
# Processing Record 45 of Set 3 | mahebourg
# Processing Record 46 of Set 3 | mildura
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | havre-saint-pierre
# Processing Record 49 of Set 3 | tiksi
# Processing Record 50 of Set 3 | lena
# Processing Record 1 of Set 4 | pandharpur
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | bilma
# Processing Record 5 of Set 4 | hirara
# Processing Record 6 of Set 4 | aljezur
# Processing Record 7 of Set 4 | susaki
# Processing Record 8 of Set 4 | warmbad
# Processing Record 9 of Set 4 | fare
# Processing Record 10 of Set 4 | vila franca do campo
# Processing Record 11 of Set 4 | negara
# Processing Record 12 of Set 4 | guaraniacu
# Processing Record 13 of Set 4 | srednebelaya
# Processing Record 14 of Set 4 | berettyoujfalu
# Processing Record 15 of Set 4 | kpagouda
# City not found. Skipping...
# Processing Record 16 of Set 4 | edmundston
# Processing Record 17 of Set 4 | manta
# Processing Record 18 of Set 4 | nuuk
# Processing Record 19 of Set 4 | camacha
# Processing Record 20 of Set 4 | omboue
# Processing Record 21 of Set 4 | riohacha
# Processing Record 22 of Set 4 | craig
# Processing Record 23 of Set 4 | alofi
# Processing Record 24 of Set 4 | hofn
# Processing Record 25 of Set 4 | el jicaro
# Processing Record 26 of Set 4 | georgiyevka
# Processing Record 27 of Set 4 | mumbwa
# Processing Record 28 of Set 4 | amalapuram
# Processing Record 29 of Set 4 | rongcheng
# Processing Record 30 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 31 of Set 4 | uglovskoye
# Processing Record 32 of Set 4 | nizhyn
# Processing Record 33 of Set 4 | ormara
# Processing Record 34 of Set 4 | necochea
# Processing Record 35 of Set 4 | ta khmau
# Processing Record 36 of Set 4 | kaseda
# Processing Record 37 of Set 4 | zhanakorgan
# Processing Record 38 of Set 4 | lazaro cardenas
# Processing Record 39 of Set 4 | ossora
# Processing Record 40 of Set 4 | minggang
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | takoradi
# Processing Record 43 of Set 4 | duekoue
# Processing Record 44 of Set 4 | hay river
# Processing Record 45 of Set 4 | goderich
# Processing Record 46 of Set 4 | charters towers
# Processing Record 47 of Set 4 | verkhnevilyuysk
# Processing Record 48 of Set 4 | mindelo
# Processing Record 49 of Set 4 | bethel
# Processing Record 50 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 1 of Set 5 | sao paulo de olivenca
# Processing Record 2 of Set 5 | iqaluit
# Processing Record 3 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 5 | devonport
# Processing Record 5 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 5 | iralaya
# Processing Record 7 of Set 5 | port alfred
# Processing Record 8 of Set 5 | sawakin
# Processing Record 9 of Set 5 | katherine
# Processing Record 10 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 5 | araguaina
# Processing Record 12 of Set 5 | taitung
# Processing Record 13 of Set 5 | severo-kurilsk
# Processing Record 14 of Set 5 | baruun-urt
# Processing Record 15 of Set 5 | aswan
# Processing Record 16 of Set 5 | cape town
# Processing Record 17 of Set 5 | amapa
# Processing Record 18 of Set 5 | sur
# Processing Record 19 of Set 5 | cap malheureux
# Processing Record 20 of Set 5 | fusagasuga
# Processing Record 21 of Set 5 | aripuana
# Processing Record 22 of Set 5 | shache
# Processing Record 23 of Set 5 | san cristobal
# Processing Record 24 of Set 5 | bambous virieux
# Processing Record 25 of Set 5 | korla
# Processing Record 26 of Set 5 | grindavik
# Processing Record 27 of Set 5 | upernavik
# Processing Record 28 of Set 5 | abnub
# Processing Record 29 of Set 5 | mangochi
# Processing Record 30 of Set 5 | te anau
# Processing Record 31 of Set 5 | omsukchan
# Processing Record 32 of Set 5 | chicama
# Processing Record 33 of Set 5 | maniitsoq
# Processing Record 34 of Set 5 | blackwater
# Processing Record 35 of Set 5 | carnarvon
# Processing Record 36 of Set 5 | port blair
# Processing Record 37 of Set 5 | paso de carrasco
# Processing Record 38 of Set 5 | gujrat
# Processing Record 39 of Set 5 | gat
# Processing Record 40 of Set 5 | tura
# Processing Record 41 of Set 5 | tsabong
# Processing Record 42 of Set 5 | longyearbyen
# Processing Record 43 of Set 5 | sovetskiy
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | sao filipe
# Processing Record 46 of Set 5 | kawalu
# Processing Record 47 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | estelle
# Processing Record 49 of Set 5 | limot
# Processing Record 50 of Set 5 | taoudenni
# Processing Record 1 of Set 6 | zhoucheng
# Processing Record 2 of Set 6 | victoria
# Processing Record 3 of Set 6 | taltal
# Processing Record 4 of Set 6 | norman wells
# Processing Record 5 of Set 6 | san patricio
# Processing Record 6 of Set 6 | quatre cocos
# Processing Record 7 of Set 6 | dryden
# Processing Record 8 of Set 6 | klaksvik
# Processing Record 9 of Set 6 | kovdor
# Processing Record 10 of Set 6 | khasan
# Processing Record 11 of Set 6 | ahar
# Processing Record 12 of Set 6 | kloulklubed
# Processing Record 13 of Set 6 | voyinka
# Processing Record 14 of Set 6 | comodoro rivadavia
# Processing Record 15 of Set 6 | viedma
# Processing Record 16 of Set 6 | constitucion
# Processing Record 17 of Set 6 | goure
# Processing Record 18 of Set 6 | vao
# Processing Record 19 of Set 6 | nome
# Processing Record 20 of Set 6 | toktogul
# Processing Record 21 of Set 6 | hasaki
# Processing Record 22 of Set 6 | dikson
# Processing Record 23 of Set 6 | zalantun
# Processing Record 24 of Set 6 | lethem
# Processing Record 25 of Set 6 | chuy
# Processing Record 26 of Set 6 | mackay
# Processing Record 27 of Set 6 | port pirie
# Processing Record 28 of Set 6 | mapiri
# Processing Record 29 of Set 6 | mumford
# Processing Record 30 of Set 6 | najran
# Processing Record 31 of Set 6 | talnakh
# Processing Record 32 of Set 6 | champoton
# Processing Record 33 of Set 6 | beringovskiy
# Processing Record 34 of Set 6 | reinosa
# Processing Record 35 of Set 6 | airai
# Processing Record 36 of Set 6 | ranong
# Processing Record 37 of Set 6 | iranshahr
# Processing Record 38 of Set 6 | kangaatsiaq
# Processing Record 39 of Set 6 | novovelichkovskaya
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | okhotsk
# Processing Record 42 of Set 6 | souillac
# Processing Record 43 of Set 6 | nemuro
# Processing Record 44 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 6 | beira
# Processing Record 46 of Set 6 | honiara
# Processing Record 47 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 48 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 49 of Set 6 | ballina
# Processing Record 50 of Set 6 | parabel
# Processing Record 1 of Set 7 | belyy yar
# Processing Record 2 of Set 7 | nishihara
# Processing Record 3 of Set 7 | santa rosa
# Processing Record 4 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 7 | porosozero
# Processing Record 6 of Set 7 | zonguldak
# Processing Record 7 of Set 7 | acuna
# City not found. Skipping...
# Processing Record 8 of Set 7 | san rafael
# Processing Record 9 of Set 7 | taksimo
# Processing Record 10 of Set 7 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 11 of Set 7 | dunedin
# Processing Record 12 of Set 7 | duku
# Processing Record 13 of Set 7 | rosetta
# Processing Record 14 of Set 7 | tuatapere
# Processing Record 15 of Set 7 | melioratorov
# Processing Record 16 of Set 7 | kihei
# Processing Record 17 of Set 7 | srandakan
# Processing Record 18 of Set 7 | leningradskiy
# Processing Record 19 of Set 7 | magadi
# Processing Record 20 of Set 7 | cesis
# Processing Record 21 of Set 7 | micheweni
# Processing Record 22 of Set 7 | vostok
# Processing Record 23 of Set 7 | bukama
# Processing Record 24 of Set 7 | hithadhoo
# Processing Record 25 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 7 | caravelas
# Processing Record 27 of Set 7 | biak
# Processing Record 28 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 29 of Set 7 | cascas
# Processing Record 30 of Set 7 | whitianga
# Processing Record 31 of Set 7 | monrovia
# Processing Record 32 of Set 7 | pochutla
# Processing Record 33 of Set 7 | sterling
# Processing Record 34 of Set 7 | madanapalle
# Processing Record 35 of Set 7 | maple creek
# Processing Record 36 of Set 7 | muisne
# Processing Record 37 of Set 7 | portland
# Processing Record 38 of Set 7 | kiunga
# Processing Record 39 of Set 7 | kutum
# Processing Record 40 of Set 7 | burica
# City not found. Skipping...
# Processing Record 41 of Set 7 | porto walter
# Processing Record 42 of Set 7 | ustyuzhna
# Processing Record 43 of Set 7 | itarema
# Processing Record 44 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 7 | ligayan
# Processing Record 46 of Set 7 | bobo dioulasso
# Processing Record 47 of Set 7 | yamada
# Processing Record 48 of Set 7 | chimbote
# Processing Record 49 of Set 7 | nouadhibou
# Processing Record 50 of Set 7 | roma
# Processing Record 1 of Set 8 | leh
# Processing Record 2 of Set 8 | marovoay
# Processing Record 3 of Set 8 | kushima
# Processing Record 4 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 8 | sao joao da barra
# Processing Record 6 of Set 8 | tecoanapa
# Processing Record 7 of Set 8 | ancud
# Processing Record 8 of Set 8 | nizhnyaya tavda
# Processing Record 9 of Set 8 | angoche
# Processing Record 10 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 8 | flinders
# Processing Record 12 of Set 8 | shiraz
# Processing Record 13 of Set 8 | pangnirtung
# Processing Record 14 of Set 8 | ust-kuyga
# Processing Record 15 of Set 8 | neuquen
# Processing Record 16 of Set 8 | minab
# Processing Record 17 of Set 8 | alamogordo
# Processing Record 18 of Set 8 | aykhal
# Processing Record 19 of Set 8 | pevek
# Processing Record 20 of Set 8 | rantepao
# Processing Record 21 of Set 8 | warrnambool
# Processing Record 22 of Set 8 | kerman
# Processing Record 23 of Set 8 | saint-leu
# Processing Record 24 of Set 8 | gorontalo
# Processing Record 25 of Set 8 | andros town
# Processing Record 26 of Set 8 | saint-philippe
# Processing Record 27 of Set 8 | dudinka
# Processing Record 28 of Set 8 | whitehorse
# Processing Record 29 of Set 8 | harper
# Processing Record 30 of Set 8 | bolshevik
# Processing Record 31 of Set 8 | hualmay
# Processing Record 32 of Set 8 | lima
# Processing Record 33 of Set 8 | xinqing
# Processing Record 34 of Set 8 | atbasar
# Processing Record 35 of Set 8 | fortuna
# Processing Record 36 of Set 8 | smithers
# Processing Record 37 of Set 8 | afikpo
# Processing Record 38 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 8 | foam lake
# Processing Record 40 of Set 8 | seoul
# Processing Record 41 of Set 8 | khandyga
# Processing Record 42 of Set 8 | sorong
# Processing Record 43 of Set 8 | palmer
# Processing Record 44 of Set 8 | tete
# Processing Record 45 of Set 8 | dumka
# Processing Record 46 of Set 8 | port arthur
# Processing Record 47 of Set 8 | sourpi
# Processing Record 48 of Set 8 | half moon bay
# Processing Record 49 of Set 8 | altagracia de orituco
# Processing Record 50 of Set 8 | ugoofaaru
# Processing Record 1 of Set 9 | camocim
# Processing Record 2 of Set 9 | zakamensk
# Processing Record 3 of Set 9 | cabangahan
# Processing Record 4 of Set 9 | vikhorevka
# Processing Record 5 of Set 9 | fort morgan
# Processing Record 6 of Set 9 | aleksandrovka
# Processing Record 7 of Set 9 | udachnyy
# Processing Record 8 of Set 9 | atherton
# Processing Record 9 of Set 9 | saint-pierre
# Processing Record 10 of Set 9 | buraydah
# Processing Record 11 of Set 9 | gombe
# Processing Record 12 of Set 9 | road town
# Processing Record 13 of Set 9 | merauke
# Processing Record 14 of Set 9 | marsh harbour
# Processing Record 15 of Set 9 | mandera
# Processing Record 16 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 9 | guerrero negro
# Processing Record 18 of Set 9 | chumphon
# Processing Record 19 of Set 9 | san policarpo
# Processing Record 20 of Set 9 | denpasar
# Processing Record 21 of Set 9 | pak phanang
# Processing Record 22 of Set 9 | sorland
# Processing Record 23 of Set 9 | saldanha
# Processing Record 24 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 9 | puerto baquerizo moreno
# Processing Record 26 of Set 9 | pietarsaari
# Processing Record 27 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 28 of Set 9 | cravo norte
# Processing Record 29 of Set 9 | pontal do parana
# Processing Record 30 of Set 9 | bima
# Processing Record 31 of Set 9 | husavik
# Processing Record 32 of Set 9 | yaring
# Processing Record 33 of Set 9 | colac
# Processing Record 34 of Set 9 | wa
# City not found. Skipping...
# Processing Record 35 of Set 9 | nara
# Processing Record 36 of Set 9 | yar-sale
# Processing Record 37 of Set 9 | tubmanburg
# Processing Record 38 of Set 9 | kalanaur
# Processing Record 39 of Set 9 | lewiston
# Processing Record 40 of Set 9 | pavilosta
# Processing Record 41 of Set 9 | praia da vitoria
# Processing Record 42 of Set 9 | qabis
# City not found. Skipping...
# Processing Record 43 of Set 9 | rozzano
# Processing Record 44 of Set 9 | porgera
# Processing Record 45 of Set 9 | puerto del rosario
# Processing Record 46 of Set 9 | bure
# Processing Record 47 of Set 9 | itoman
# Processing Record 48 of Set 9 | buta
# Processing Record 49 of Set 9 | lata
# Processing Record 50 of Set 9 | praya
# Processing Record 1 of Set 10 | lavrentiya
# Processing Record 2 of Set 10 | porto nacional
# Processing Record 3 of Set 10 | sorkjosen
# Processing Record 4 of Set 10 | dalby
# Processing Record 5 of Set 10 | dingle
# Processing Record 6 of Set 10 | yuli
# Processing Record 7 of Set 10 | zhangjiakou
# Processing Record 8 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 10 | moron
# Processing Record 11 of Set 10 | ostersund
# Processing Record 12 of Set 10 | saint-francois
# Processing Record 13 of Set 10 | saurimo
# Processing Record 14 of Set 10 | nanortalik
# Processing Record 15 of Set 10 | mangrol
# Processing Record 16 of Set 10 | pangkalanbuun
# Processing Record 17 of Set 10 | oranjemund
# Processing Record 18 of Set 10 | samana
# Processing Record 19 of Set 10 | marystown
# Processing Record 20 of Set 10 | lubumbashi
# Processing Record 21 of Set 10 | burns lake
# Processing Record 22 of Set 10 | san andres
# Processing Record 23 of Set 10 | novobirilyussy
# Processing Record 24 of Set 10 | sola
# Processing Record 25 of Set 10 | chkalovsk
# Processing Record 26 of Set 10 | penzance
# Processing Record 27 of Set 10 | tamandare
# Processing Record 28 of Set 10 | derzhavinsk
# Processing Record 29 of Set 10 | aklavik
# Processing Record 30 of Set 10 | bloemfontein
# Processing Record 31 of Set 10 | ohafia
# Processing Record 32 of Set 10 | nanakuli
# Processing Record 33 of Set 10 | padang
# Processing Record 34 of Set 10 | ayagoz
# Processing Record 35 of Set 10 | metro
# Processing Record 36 of Set 10 | bambanglipuro
# Processing Record 37 of Set 10 | ayan
# Processing Record 38 of Set 10 | taga
# Processing Record 39 of Set 10 | chapais
# Processing Record 40 of Set 10 | florence
# Processing Record 41 of Set 10 | pingliang
# Processing Record 42 of Set 10 | geraldton
# Processing Record 43 of Set 10 | sabla
# Processing Record 44 of Set 10 | onverwacht
# Processing Record 45 of Set 10 | sug-aksy
# City not found. Skipping...
# Processing Record 46 of Set 10 | zhigansk
# Processing Record 47 of Set 10 | rincon
# Processing Record 48 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 10 | alta floresta
# Processing Record 50 of Set 10 | paka
# Processing Record 1 of Set 11 | havelock
# Processing Record 2 of Set 11 | dehloran
# Processing Record 3 of Set 11 | kathmandu
# Processing Record 4 of Set 11 | port lincoln
# Processing Record 5 of Set 11 | namatanai
# Processing Record 6 of Set 11 | kahului
# Processing Record 7 of Set 11 | yoichi
# Processing Record 8 of Set 11 | nelson bay
# Processing Record 9 of Set 11 | berbera
# Processing Record 10 of Set 11 | biltine
# Processing Record 11 of Set 11 | yulara
# Processing Record 12 of Set 11 | andrews
# Processing Record 13 of Set 11 | bennington
# Processing Record 14 of Set 11 | conakry
# Processing Record 15 of Set 11 | orange cove
# Processing Record 16 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 11 | lorengau
# Processing Record 18 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 11 | sao felix do xingu
# Processing Record 20 of Set 11 | chake chake
# Processing Record 21 of Set 11 | shakhrinau
# City not found. Skipping...
# Processing Record 22 of Set 11 | kingsville
# Processing Record 23 of Set 11 | umm lajj
# Processing Record 24 of Set 11 | pokhara
# Processing Record 25 of Set 11 | galle
# Processing Record 26 of Set 11 | salinopolis
# Processing Record 27 of Set 11 | vytegra
# Processing Record 28 of Set 11 | codrington
# Processing Record 29 of Set 11 | belle fourche
# Processing Record 30 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 11 | progreso
# Processing Record 32 of Set 11 | coquimbo
# Processing Record 33 of Set 11 | roebourne
# Processing Record 34 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 11 | touros
# Processing Record 39 of Set 11 | robertsport
# Processing Record 40 of Set 11 | darhan
# Processing Record 41 of Set 11 | saint-augustin
# Processing Record 42 of Set 11 | nadvoitsy
# Processing Record 43 of Set 11 | homer
# Processing Record 44 of Set 11 | lagoa
# Processing Record 45 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 11 | siocon
# Processing Record 47 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 11 | santo tomas
# Processing Record 49 of Set 11 | bocas del toro
# Processing Record 50 of Set 11 | caluquembe
# Processing Record 1 of Set 12 | machico
# Processing Record 2 of Set 12 | verkhnetulomskiy
# Processing Record 3 of Set 12 | kenai
# Processing Record 4 of Set 12 | lompoc
# Processing Record 5 of Set 12 | paamiut
# Processing Record 6 of Set 12 | borova
# Processing Record 7 of Set 12 | dukat
# Processing Record 8 of Set 12 | kavieng
# Processing Record 9 of Set 12 | cayenne
# Processing Record 10 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 12 | golden
# Processing Record 12 of Set 12 | lazo
# Processing Record 13 of Set 12 | uppsala
# Processing Record 14 of Set 12 | olkhovatka
# Processing Record 15 of Set 12 | tres arroyos
# Processing Record 16 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 12 | barwadih
# Processing Record 18 of Set 12 | pueblo nuevo
# Processing Record 19 of Set 12 | general roca
# Processing Record 20 of Set 12 | baijiantan
# Processing Record 21 of Set 12 | price
# Processing Record 22 of Set 12 | urumqi
# Processing Record 23 of Set 12 | kodiak
# Processing Record 24 of Set 12 | belmonte
# Processing Record 25 of Set 12 | fort saint james
# Processing Record 26 of Set 12 | baykalsk
# Processing Record 27 of Set 12 | galanta
# Processing Record 28 of Set 12 | lakes entrance
# Processing Record 29 of Set 12 | basoko
# Processing Record 30 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 12 | svetlogorsk
# Processing Record 32 of Set 12 | ahuimanu
# Processing Record 33 of Set 12 | rawson
# Processing Record 34 of Set 12 | jasper
# Processing Record 35 of Set 12 | hauterive
# Processing Record 36 of Set 12 | denia
# Processing Record 37 of Set 12 | gumushane
# City not found. Skipping...
# Processing Record 38 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 39 of Set 12 | portobelo
# Processing Record 40 of Set 12 | salalah
# Processing Record 41 of Set 12 | collie
# Processing Record 42 of Set 12 | matara
# Processing Record 43 of Set 12 | marawi
# Processing Record 44 of Set 12 | erenhot
# Processing Record 45 of Set 12 | kabare
# Processing Record 46 of Set 12 | coahuayana
# Processing Record 47 of Set 12 | mackenzie
# Processing Record 48 of Set 12 | ust-tsilma
# Processing Record 49 of Set 12 | morgan city
# Processing Record 50 of Set 12 | sisimiut
# Processing Record 1 of Set 13 | bintulu
# Processing Record 2 of Set 13 | wakiso
# Processing Record 3 of Set 13 | dhidhdhoo
# Processing Record 4 of Set 13 | makinsk
# Processing Record 5 of Set 13 | avera
# Processing Record 6 of Set 13 | mizan teferi
# Processing Record 7 of Set 13 | tupik
# Processing Record 8 of Set 13 | zhanaozen
# Processing Record 9 of Set 13 | serra talhada
# Processing Record 10 of Set 13 | port augusta
# Processing Record 11 of Set 13 | san rafael del sur
# Processing Record 12 of Set 13 | westport
# Processing Record 13 of Set 13 | ocos
# Processing Record 14 of Set 13 | aguilas
# Processing Record 15 of Set 13 | auki
# Processing Record 16 of Set 13 | pousat
# City not found. Skipping...
# Processing Record 17 of Set 13 | verkhneuralsk
# Processing Record 18 of Set 13 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 19 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 20 of Set 13 | gizo
# Processing Record 21 of Set 13 | kaitong
# Processing Record 22 of Set 13 | muros
# Processing Record 23 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 13 | komsomolskiy
# Processing Record 25 of Set 13 | yuxia
# Processing Record 26 of Set 13 | havoysund
# Processing Record 27 of Set 13 | sakakah
# Processing Record 28 of Set 13 | meaux
# Processing Record 29 of Set 13 | alamos
# Processing Record 30 of Set 13 | sadove
# Processing Record 31 of Set 13 | edea
# Processing Record 32 of Set 13 | college
# Processing Record 33 of Set 13 | colares
# Processing Record 34 of Set 13 | kanturk
# Processing Record 35 of Set 13 | alyangula
# Processing Record 36 of Set 13 | tawau
# Processing Record 37 of Set 13 | akureyri
# Processing Record 38 of Set 13 | kulhudhuffushi
# Processing Record 39 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 13 | north platte
# Processing Record 41 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 13 | habra
# Processing Record 43 of Set 13 | eyrarbakki
# Processing Record 44 of Set 13 | mantsala
# Processing Record 45 of Set 13 | deputatskiy
# Processing Record 46 of Set 13 | guilin
# Processing Record 47 of Set 13 | kanke
# Processing Record 48 of Set 13 | cooma
# Processing Record 49 of Set 13 | nalut
# Processing Record 50 of Set 13 | saint-georges
# Processing Record 1 of Set 14 | rotava
# Processing Record 2 of Set 14 | tilichiki
# Processing Record 3 of Set 14 | miri
# Processing Record 4 of Set 14 | kembe
# Processing Record 5 of Set 14 | kendari
# Processing Record 6 of Set 14 | bathsheba
# Processing Record 7 of Set 14 | cururupu
# Processing Record 8 of Set 14 | harer
# Processing Record 9 of Set 14 | nouakchott
# Processing Record 10 of Set 14 | mana
# Processing Record 11 of Set 14 | joao pinheiro
# Processing Record 12 of Set 14 | copalillo
# Processing Record 13 of Set 14 | katsuura
# Processing Record 14 of Set 14 | mitsamiouli
# Processing Record 15 of Set 14 | moranbah
# Processing Record 16 of Set 14 | hendrina
# Processing Record 17 of Set 14 | falesti
# Processing Record 18 of Set 14 | webuye
# Processing Record 19 of Set 14 | puerto cortes
# City not found. Skipping...
# Processing Record 20 of Set 14 | san carlos de bariloche
# Processing Record 21 of Set 14 | saint simons
# Processing Record 22 of Set 14 | chumikan
# Processing Record 23 of Set 14 | fano
# Processing Record 24 of Set 14 | north bend
# Processing Record 25 of Set 14 | kirakira
# Processing Record 26 of Set 14 | ojinaga
# Processing Record 27 of Set 14 | ixtapa
# Processing Record 28 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 14 | grand-lahou
# Processing Record 30 of Set 14 | masingbi
# Processing Record 31 of Set 14 | opuwo
# Processing Record 32 of Set 14 | baykit
# Processing Record 33 of Set 14 | sheridan
# Processing Record 34 of Set 14 | wloclawek
# Processing Record 35 of Set 14 | rockhampton
# Processing Record 36 of Set 14 | port-gentil
# Processing Record 37 of Set 14 | west wendover
# Processing Record 38 of Set 14 | khani
# Processing Record 39 of Set 14 | boffa
# Processing Record 40 of Set 14 | mokhsogollokh
# Processing Record 41 of Set 14 | mount pleasant
# Processing Record 42 of Set 14 | katha
# City not found. Skipping...
# Processing Record 43 of Set 14 | san juan
# Processing Record 44 of Set 14 | qasigiannguit
# Processing Record 45 of Set 14 | sao gabriel da cachoeira
# Processing Record 46 of Set 14 | gidam
# Processing Record 47 of Set 14 | north vanlaiphai
# Processing Record 48 of Set 14 | bajil
# Processing Record 49 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 14 | lakota
# Processing Record 1 of Set 15 | xuanzhou
# Processing Record 2 of Set 15 | celestun
# Processing Record 3 of Set 15 | jamnagar
# Processing Record 4 of Set 15 | ulubaria
# City not found. Skipping...
# Processing Record 5 of Set 15 | guangyuan
# Processing Record 6 of Set 15 | morondava
# Processing Record 7 of Set 15 | makat
# Processing Record 8 of Set 15 | correntina
# Processing Record 9 of Set 15 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 10 of Set 15 | jian
# Processing Record 11 of Set 15 | male
# Processing Record 12 of Set 15 | toora-khem
# Processing Record 13 of Set 15 | karpogory
# Processing Record 14 of Set 15 | teresopolis
# Processing Record 15 of Set 15 | todos santos
# Processing Record 16 of Set 15 | quelimane
# Processing Record 17 of Set 15 | miraflores
# Processing Record 18 of Set 15 | nerchinskiy zavod
# Processing Record 19 of Set 15 | srednekolymsk
# Processing Record 20 of Set 15 | shirokiy
# Processing Record 21 of Set 15 | huangmei
# Processing Record 22 of Set 15 | siderno
# Processing Record 23 of Set 15 | qaqortoq
# Processing Record 24 of Set 15 | gamba
# Processing Record 25 of Set 15 | vanavara
# Processing Record 26 of Set 15 | andenes
# Processing Record 27 of Set 15 | orgun
# City not found. Skipping...
# Processing Record 28 of Set 15 | alice springs
# Processing Record 29 of Set 15 | drayton valley
# Processing Record 30 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 15 | cockburn harbour
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 731

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bluff -46.6000  168.3333     65.80        64          90       19.55
# 1     Ushuaia -54.8000  -68.3000     47.86        87           0        4.61
# 2       Vaini -21.2000 -175.2000     80.76        69          20        9.22
# 3  Chokurdakh  70.6333  147.9167      5.05        93         100       18.14
# 4        Vila  42.0304   -8.1588     47.28        91          10        4.92
#
#   Country
# 0      NZ
# 1      AR
# 2      TO
# 3      RU
# 4      PT

# %%
city_data_df.count()
# Out:
# City          662
# Lat           662
# Lng           662
# Max Temp      662
# Humidity      662
# Cloudiness    662
# Wind Speed    662
# Country       662
# dtype: int64

# %%
output_data_file = 'Weatherpy_database.csv'
city_data_df.to_csv(output_data_file, index_label='City_ID')
